# %% [markdown]
# # Build OEWN Indexes
#
# Thin Colab wrapper around `scripts/build_index.py`. Edit the config path and PoS selector below, then run the cells.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## Get The Repository
#
# Use either `git clone` for a fresh Colab session or set `REPO_DIR` to a Drive folder that already contains the repository.

# %%
REPO_URL = "https://github.com/your-user/inspicio.git"
REPO_DIR = "/content/inspicio"

import os
if not os.path.exists(REPO_DIR):
    # !git clone {REPO_URL} {REPO_DIR}
# %cd {REPO_DIR}

# %%
# %pip install -q -r requirements.txt
# %pip install -q "sentence-transformers" "transformers"

# %% [markdown]
# ## Configure

# %%
CONFIG = "configs/deepseek_openai.yaml"
POS = "all"  # one of: all, verb, noun, adjective, adverb

# For API embedders, set the relevant key here or in Colab secrets.
# import os
# os.environ["OPENAI_API_KEY"] = "..."
# os.environ["COHERE_API_KEY"] = "..."

# %%
# !python scripts/build_index.py --config {CONFIG} --pos {POS}

# %% [markdown]
# ## Save Indexes To Drive
#
# Set `INDEX_DIR` to the Chroma directory you built, then zip it for download or Drive storage.

# %%
INDEX_DIR = "./oewn_verb_embeddings"
ZIP_NAME = "oewn_verb_embeddings"

import shutil
shutil.make_archive(ZIP_NAME, "zip", ".", INDEX_DIR)
print(f"Created {ZIP_NAME}.zip")
